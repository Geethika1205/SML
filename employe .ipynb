# %% [markdown]
# <a href="https://colab.research.google.com/github/Geethika1205/SML/blob/main/employe%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/employee_survey.csv")

# %%
df
# Out:
#       EmpID  Gender  Age MaritalStatus        JobLevel  Experience       Dept  \
# 0         6    Male   32       Married             Mid           7         IT
# 1        11  Female   34       Married             Mid          12    Finance
# 2        33  Female   23        Single  Intern/Fresher           1  Marketing
# 3        20  Female   29       Married          Junior           6         IT
# 4        28   Other   23        Single          Junior           1      Sales
# ...     ...     ...  ...           ...             ...         ...        ...
# 3020   2070    Male   47       Married            Lead          16  Marketing
# 3021   2072  Female   47       Married            Lead           8         IT
# 3022   2145    Male   41       Married            Lead          17         IT
# 3023   2168  Female   54       Married            Lead          16         IT
# 3024   2183  Female   44       Married            Lead          22  Marketing
#
# ...

# %%
df['Gender']=df['Gender'].replace({'Male':0,'Female':1,'Other':2})
df['MaritalStatus'] = df['MaritalStatus'].replace({'Single': 0, 'Married': 1})
df['JobLevel'] = df['JobLevel'].replace({'Junior':0,'Mid': 1, 'Lead': 2,'Intern/Fresher':3})
df['EmpType'] = df['EmpType'].replace({'Part-Time': 0, 'Full-Time': 1,'Contract':2})

# %%
df
# Out:
#       EmpID  Gender  Age MaritalStatus JobLevel  Experience       Dept  \
# 0         6       0   32             1        1           7         IT
# 1        11       1   34             1        1          12    Finance
# 2        33       1   23             0        3           1  Marketing
# 3        20       1   29             1        0           6         IT
# 4        28       2   23             0        0           1      Sales
# ...     ...     ...  ...           ...      ...         ...        ...
# 3020   2070       0   47             1        2          16  Marketing
# 3021   2072       1   47             1        2           8         IT
# 3022   2145       0   41             1        2          17         IT
# 3023   2168       1   54             1        2          16         IT
# 3024   2183       1   44             1        2          22  Marketing
#
#       EmpType  WLB  WorkEnv  ...  SleepHours       CommuteMode  \
# ...

# %%
df['haveOT']=df['haveOT'].replace({'False':1,'True':0})

# %%
df
# Out:
#       EmpID  Gender  Age MaritalStatus JobLevel  Experience       Dept  \
# 0         6       0   32             1        1           7         IT
# 1        11       1   34             1        1          12    Finance
# 2        33       1   23             0        3           1  Marketing
# 3        20       1   29             1        0           6         IT
# 4        28       2   23             0        0           1      Sales
# ...     ...     ...  ...           ...      ...         ...        ...
# 3020   2070       0   47             1        2          16  Marketing
# 3021   2072       1   47             1        2           8         IT
# 3022   2145       0   41             1        2          17         IT
# 3023   2168       1   54             1        2          16         IT
# 3024   2183       1   44             1        2          22  Marketing
#
#       EmpType  WLB  WorkEnv  ...  SleepHours       CommuteMode  \
# ...

# %%
df.drop('Dept',inplace=True,axis=1)

# %%
df.drop('CommuteMode',inplace=True,axis=1)

# %%
df.drop('EduLevel',inplace=True,axis=1)

# %%
df.drop('haveOT',inplace=True,axis=1)

# %%
df
# Out:
#       EmpID  Gender  Age MaritalStatus JobLevel  Experience  EmpType  WLB  \
# 0         6       0   32             1        1           7        1    1
# 1        11       1   34             1        1          12        1    1
# 2        33       1   23             0        3           1        1    2
# 3        20       1   29             1        0           6        2    2
# 4        28       2   23             0        0           1        0    3
# ...     ...     ...  ...           ...      ...         ...      ...  ...
# 3020   2070       0   47             1        2          16        0    1
# 3021   2072       1   47             1        2           8        2    3
# 3022   2145       0   41             1        2          17        1    1
# 3023   2168       1   54             1        2          16        1    1
# 3024   2183       1   44             1        2          22        1    3
#
#       WorkEnv  PhysicalActivityHours  Workload  Stress  SleepHours  \
# ...

# %%
y=df['JobSatisfaction']
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 3020    1
# 3021    1
# 3022    1
# 3023    1
# 3024    1
# Name: JobSatisfaction, Length: 3025, dtype: int64

# %%
x=df.drop('JobSatisfaction',axis=1)
x
# Out:
#       EmpID  Gender  Age MaritalStatus JobLevel  Experience  EmpType  WLB  \
# 0         6       0   32             1        1           7        1    1
# 1        11       1   34             1        1          12        1    1
# 2        33       1   23             0        3           1        1    2
# 3        20       1   29             1        0           6        2    2
# 4        28       2   23             0        0           1        0    3
# ...     ...     ...  ...           ...      ...         ...      ...  ...
# 3020   2070       0   47             1        2          16        0    1
# 3021   2072       1   47             1        2           8        2    3
# 3022   2145       0   41             1        2          17        1    1
# 3023   2168       1   54             1        2          16        1    1
# 3024   2183       1   44             1        2          22        1    3
#
#       WorkEnv  PhysicalActivityHours  Workload  Stress  SleepHours  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-22d9f8bbfa69> in <cell line: 5>()
#       3 X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
#       4 model = LogisticRegression()
# ----> 5 model.fit(X_train, y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1221             _dtype = [np.float64, np.float32]
#    1222
# -> 1223         X, y = self._validate_data(
#    1224             X,
#    1225             y,
#
# ...
