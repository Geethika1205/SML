# %% [markdown]
# <a href="https://colab.research.google.com/github/Geethika1205/SML/blob/main/Untitled34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/Train.csv")

# %%
df
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
df.head(220)
# Out:
#          ID  Gender Ever_Married  Age Graduated     Profession  \
# 0    462809    Male           No   22        No     Healthcare
# 1    462643  Female          Yes   38       Yes       Engineer
# 2    466315  Female          Yes   67       Yes       Engineer
# 3    461735    Male          Yes   67       Yes         Lawyer
# 4    462669  Female          Yes   40       Yes  Entertainment
# ..      ...     ...          ...  ...       ...            ...
# 215  462742    Male           No   18        No     Healthcare
# 216  459528  Female          Yes   52       Yes         Doctor
# 217  462691    Male          Yes   25        No         Doctor
# 218  462934    Male          Yes   56        No      Executive
# 219  465837    Male           No   62       Yes            NaN
#
#      Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                1.0            Low          4.0  Cat_4            D
# 1                NaN        Average          3.0  Cat_4            A
# ...

# %%
df['Ever_Married']=df['Ever_Married'].replace({'No':0,'Yes':1})
df['Gender'] = df['Gender'].replace({'Female': 0, 'Male': 1})
df['Spending_Score'] = df['Spending_Score'].replace({'High': 1, 'Low': 0,'Average':2})
df
# Out:
#           ID  Gender  Ever_Married  Age Graduated     Profession  \
# 0     462809       1           0.0   22        No     Healthcare
# 1     462643       0           1.0   38       Yes       Engineer
# 2     466315       0           1.0   67       Yes       Engineer
# 3     461735       1           1.0   67       Yes         Lawyer
# 4     462669       0           1.0   40       Yes  Entertainment
# ...      ...     ...           ...  ...       ...            ...
# 8063  464018       1           0.0   22        No            NaN
# 8064  464685       1           0.0   35        No      Executive
# 8065  465406       0           0.0   33       Yes     Healthcare
# 8066  467299       0           0.0   27       Yes     Healthcare
# 8067  461879       1           1.0   37       Yes      Executive
#
#       Work_Experience  Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0               0          4.0  Cat_4            D
# ...

# %%
df['Ever_Married']=df['Ever_Married'].replace({'No':0,'Yes':1})
df['Gender'] = df['Gender'].replace({'Female': 0, 'Male': 1})
df['Spending_Score'] = df['Spending_Score'].replace({'High': 1, 'Low': 0,'Average':2})
df
