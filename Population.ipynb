# %% [markdown]
# <a href="https://colab.research.google.com/github/Geethika1205/SML/blob/main/Population.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/Wprld population growth rate by cities 2024 (1).csv")

# %%
df
# Out:
#                City         Country      Continent  Population (2024)  \
# 0             Tokyo           Japan           Asia           37115035
# 1             Delhi           India           Asia           33807403
# 2          Shanghai           China           Asia           29867918
# 3             Dhaka      Bangladesh           Asia           23935652
# 4         Sao Paulo          Brazil  South America           22806704
# ..              ...             ...            ...                ...
# 796       Bhavnagar           India           Asia             751493
# 797       Sheffield  United Kingdom         Europe             751303
# 798          Huambo          Angola         Africa             751297
# 799  Ribeirao Preto          Brazil  South America             750174
# 800       Panzhihua           China           Asia             750036
#
#      Population (2023)  Growth Rate
# 0             37194105      -0.0021
# 1             32941309       0.0263
# ...

# %%
df.head(200)
# Out:
#           City        Country      Continent  Population (2024)  \
# 0        Tokyo          Japan           Asia           37115035
# 1        Delhi          India           Asia           33807403
# 2     Shanghai          China           Asia           29867918
# 3        Dhaka     Bangladesh           Asia           23935652
# 4    Sao Paulo         Brazil  South America           22806704
# ..         ...            ...            ...                ...
# 195    Sapporo          Japan           Asia            2660947
# 196   Tashkent     Uzbekistan           Asia            2633661
# 197      Patna          India           Asia            2633243
# 198     Bhopal          India           Asia            2624865
# 199    Chicago  United States  North America            2590002
#
#      Population (2023)  Growth Rate
# 0             37194105      -0.0021
# 1             32941309       0.0263
# 2             29210808       0.0225
# 3             23209616       0.0313
# ...

# %%
df.drop('City',inplace=True,axis=1)

# %%
df.drop('Country',inplace=True,axis=1)

# %%
df
# Out:
#          Continent  Population (2024)  Population (2023)  Growth Rate
# 0             Asia           37115035           37194105      -0.0021
# 1             Asia           33807403           32941309       0.0263
# 2             Asia           29867918           29210808       0.0225
# 3             Asia           23935652           23209616       0.0313
# 4    South America           22806704           22619736       0.0083
# ..             ...                ...                ...          ...
# 796           Asia             751493             737128       0.0195
# 797         Europe             751303             745876       0.0073
# 798         Africa             751297             727641       0.0325
# 799  South America             750174             742115       0.0109
# 800           Asia             750036             738495       0.0156
#
# [801 rows x 4 columns]

# %%
df.drop('Continent',inplace=True,axis=1)

# %%
df
# Out:
#      Population (2024)  Population (2023)  Growth Rate
# 0             37115035           37194105      -0.0021
# 1             33807403           32941309       0.0263
# 2             29867918           29210808       0.0225
# 3             23935652           23209616       0.0313
# 4             22806704           22619736       0.0083
# ..                 ...                ...          ...
# 796             751493             737128       0.0195
# 797             751303             745876       0.0073
# 798             751297             727641       0.0325
# 799             750174             742115       0.0109
# 800             750036             738495       0.0156
#
# [801 rows x 3 columns]

# %%
y=df['Growth Rate']

# %%
y
# Out:
# 0     -0.0021
# 1      0.0263
# 2      0.0225
# 3      0.0313
# 4      0.0083
#         ...
# 796    0.0195
# 797    0.0073
# 798    0.0325
# 799    0.0109
# 800    0.0156
# Name: Growth Rate, Length: 801, dtype: float64

# %%
x=df.drop('Growth Rate',axis=1)
x
# Out:
#      Population (2024)  Population (2023)
# 0             37115035           37194105
# 1             33807403           32941309
# 2             29867918           29210808
# 3             23935652           23209616
# 4             22806704           22619736
# ..                 ...                ...
# 796             751493             737128
# 797             751303             745876
# 798             751297             727641
# 799             750174             742115
# 800             750036             738495
#
# [801 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
x_test
# Out:
#      Population (2024)  Population (2023)
# 27            11436004           11248839
# 334            1609261            1568025
# 646             930620             910743
# 392            1406091            1376453
# 495            1179301            1161448
# ..                 ...                ...
# 665             909676             908823
# 157            3120340            3088414
# 370            1480470            1451748
# 717             829361             804537
# 311            1719604            1700066
#
# [161 rows x 2 columns]

# %%
y_test
# Out:
# 27     0.0166
# 334    0.0263
# 646    0.0218
# 392    0.0215
# 495    0.0154
#         ...
# 665    0.0009
# 157    0.0103
# 370    0.0198
# 717    0.0309
# 311    0.0115
# Name: Growth Rate, Length: 161, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 0.01802247,  0.02135118,  0.02014708,  0.02032925,  0.01933614,
#         0.01930742,  0.02650007,  0.01858044,  0.01436893,  0.01972661,
#         0.00771051,  0.02173419,  0.02955623,  0.02526256,  0.02212217,
#         0.01904539,  0.01954343,  0.01980291,  0.02436612,  0.01867285,
#         0.01886615,  0.02004009,  0.02471337,  0.02209987,  0.02354072,
#         0.02265523,  0.01920632,  0.0200511 ,  0.02051391,  0.02130155,
#         0.01585916,  0.01825124,  0.02218505,  0.0201853 ,  0.01661194,
#         0.02070772,  0.01695138,  0.02062789,  0.03625947,  0.02126944,
#         0.02048463,  0.02009876,  0.02039617,  0.02050842,  0.02182094,
#         0.03119362,  0.02028333,  0.02090409,  0.01894657,  0.01951424,
#         0.01996496,  0.02487449,  0.01803837,  0.02010256,  0.01876348,
#         0.0186773 ,  0.02047139,  0.01712296,  0.02081004,  0.02052035,
#         0.02226993,  0.01890889,  0.0199718 ,  0.01888856,  0.02311176,
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.3978422653327879

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)
print(mse)
# Out:
# 7.885819920412312e-05

# %%
msa=mean_absolute_error(y_test,y_pred)
print(msa)
# Out:
# 0.006659019940232724

# %%
rmse=root_mean_squared_error(y_test,y_pred)
print(rmse)
# Out:
# 0.008880213916574483

# %%
from sklearn.linear_model import Ridge
model=Ridge()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.39784226533235556

# %%
mse=mean_squared_error(y_test,y_pred)
print(mse)
# Out:
# 7.885819920417973e-05

# %%
msa=mean_absolute_error(y_test,y_pred)
print(msa)
# Out:
# 0.006659019940236927

# %%
rmse=root_mean_squared_error(y_test,y_pred)
print(rmse)
# Out:
# 0.008880213916577671

# %%
from sklearn.linear_model import Lasso
model=Lasso()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.358e-02, tolerance: 9.760e-06
#   model = cd_fast.enet_coordinate_descent(
# 0.10272589202745463

# %%
mse=mean_squared_error(y_test,y_pred)
print(mse)
# Out:
# 0.00011750645432845863

# %%
msa=mean_absolute_error(y_test,y_pred)
print(msa)
# Out:
# 0.008381786837903988

# %%
rmse=root_mean_squared_error(y_test,y_pred)
print(rmse)
# Out:
# 0.010840039406222591

# %%
from sklearn.svm import SVR
ss=SVR()
mm=ss.fit(x_train,y_train)
print(mm.intercept_)
# Out:
# [0.01665]
